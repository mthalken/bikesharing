# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
citibike_df = pd.read_csv("201908-citibike-tripdata.csv")
citibike_df.head(25)

# %%
# 2. Check the datatypes of your columns. 
citibike_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citibike_df['tripduration'] = pd.to_datetime(citibike_df['tripduration'])

# %%
# 4. Check the datatypes of your columns. 
citibike_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# tripduation                datetime64[ns]
# dtype: object

# %%
citibike_df.head(25)
# Out:
#                     tripduration                 starttime  \
# 0  1970-01-01 00:00:00.000000393  2019-08-01 00:00:01.4680
# 1  1970-01-01 00:00:00.000000627  2019-08-01 00:00:01.9290
# 2  1970-01-01 00:00:00.000001132  2019-08-01 00:00:04.0480
# 3  1970-01-01 00:00:00.000001780  2019-08-01 00:00:04.1630
# 4  1970-01-01 00:00:00.000001517  2019-08-01 00:00:05.4580
# 5  1970-01-01 00:00:00.000000632  2019-08-01 00:00:11.8060
# 6  1970-01-01 00:00:00.000000117  2019-08-01 00:00:18.2010
# 7  1970-01-01 00:00:00.000000378  2019-08-01 00:00:22.0840
# 8  1970-01-01 00:00:00.000001102  2019-08-01 00:00:22.0870
# 9  1970-01-01 00:00:00.000001733  2019-08-01 00:00:22.5580
# 10 1970-01-01 00:00:00.000000885  2019-08-01 00:00:27.3260
# 11 1970-01-01 00:00:00.000000505  2019-08-01 00:00:30.6680
# 12 1970-01-01 00:00:00.000000620  2019-08-01 00:00:33.1190
# 13 1970-01-01 00:00:00.000000308  2019-08-01 00:00:33.9150
# 14 1970-01-01 00:00:00.000000645  2019-08-01 00:00:42.8120
# 15 1970-01-01 00:00:00.000000510  2019-08-01 00:00:44.6490
# 16 1970-01-01 00:00:00.000001758  2019-08-01 00:00:49.6330
# 17 1970-01-01 00:00:00.000001692  2019-08-01 00:00:56.0160
# 18 1970-01-01 00:00:00.000001332  2019-08-01 00:00:57.9160
# 19 1970-01-01 00:00:00.000001295  2019-08-01 00:01:04.6630
# 20 1970-01-01 00:00:00.000000506  2019-08-01 00:01:05.2950
# 21 1970-01-01 00:00:00.000000085  2019-08-01 00:01:05.4230
# 22 1970-01-01 00:00:00.000000440  2019-08-01 00:01:10.3370
# 23 1970-01-01 00:00:00.000001537  2019-08-01 00:01:14.1300
# 24 1970-01-01 00:00:00.000000824  2019-08-01 00:01:18.0540
#
#                     stoptime  start station id  \
# 0   2019-08-01 00:06:35.3780             531.0
# 1   2019-08-01 00:10:29.7840             274.0
# 2   2019-08-01 00:18:56.1650            2000.0
# 3   2019-08-01 00:29:44.7940             479.0
# 4   2019-08-01 00:25:23.4550            3312.0
# 5   2019-08-01 00:10:43.9590             173.0
# 6   2019-08-01 00:02:15.8600            3718.0
# 7   2019-08-01 00:06:40.9350             493.0
# 8   2019-08-01 00:18:44.3890             355.0
# 9   2019-08-01 00:29:15.9080             513.0
# 10  2019-08-01 00:15:12.6400             532.0
# 11  2019-08-01 00:08:56.0820             497.0
# 12  2019-08-01 00:10:53.4140            3779.0
# 13  2019-08-01 00:05:42.7430            3137.0
# 14  2019-08-01 00:11:28.7760             251.0
# 15  2019-08-01 00:09:14.9380             447.0
# 16  2019-08-01 00:30:08.4620             259.0
# 17  2019-08-01 00:29:08.0900             514.0
# 18  2019-08-01 00:23:10.4150             529.0
# 19  2019-08-01 00:22:39.8380             460.0
# 20  2019-08-01 00:09:31.3120             368.0
# 21  2019-08-01 00:02:30.5410            3140.0
# 22  2019-08-01 00:08:30.5800             531.0
# 23  2019-08-01 00:26:51.9070            3774.0
# 24  2019-08-01 00:15:02.5770            3296.0
#
#                 start station name  start station latitude  \
# 0           Forsyth St & Broome St               40.718939
# 1   Lafayette Ave & Fort Greene Pl               40.686919
# 2         Front St & Washington St               40.702551
# 3                  9 Ave & W 45 St               40.760193
# 4                  1 Ave & E 94 St               40.781721
# 5               Broadway & W 49 St               40.760683
# 6               E 11 St & Avenue B               40.727464
# 7                  W 45 St & 6 Ave               40.756800
# 8            Bayard St & Baxter St               40.716021
# 9                 W 56 St & 10 Ave               40.768254
# 10                 S 5 Pl & S 5 St               40.710451
# 11              E 17 St & Broadway               40.737050
# 12           Hart St & Wyckoff Ave               40.704876
# 13                 5 Ave & E 73 St               40.772828
# 14             Mott St & Prince St               40.723180
# 15                 8 Ave & W 52 St               40.763707
# 16         South St & Whitehall St               40.701221
# 17                12 Ave & W 40 St               40.760875
# 18                 W 42 St & 8 Ave               40.757570
# 19              S 4 St & Wythe Ave               40.712859
# 20              Carmine St & 6 Ave               40.730386
# 21                 1 Ave & E 78 St               40.771404
# 22          Forsyth St & Broome St               40.718939
# 23   Knickerbocker Ave & George St               40.704425
# 24                 E 93 St & 2 Ave               40.782454
#
#     start station longitude  end station id             end station name  \
# 0                -73.992663           408.0        Market St & Cherry St
# 1                -73.976682          3409.0         Bergen St & Smith St
# 2                -73.989402          3388.0      President St & Henry St
# 3                -73.991255           473.0   Rivington St & Chrystie St
# 4                -73.945940          3312.0              1 Ave & E 94 St
# 5                -73.984527          3707.0      Lexington Ave & E 26 St
# 6                -73.979504           326.0              E 11 St & 1 Ave
# 7                -73.982912          3724.0   7 Ave & Central Park South
# 8                -73.999744          3232.0          Bond St & Fulton St
# 9                -73.988639           469.0           Broadway & W 53 St
# 10               -73.960876           317.0            E 6 St & Avenue B
# 11               -73.990093           432.0            E 7 St & Avenue A
# 12               -73.919911          3074.0  Montrose Ave & Bushwick Ave
# 13               -73.966853          3372.0              E 74 St & 1 Ave
# 14               -73.994800           223.0              W 13 St & 7 Ave
# 15               -73.985162          3712.0           W 35 St & Dyer Ave
# 16               -74.012342           285.0           Broadway & E 14 St
# 17               -74.002777           422.0             W 59 St & 10 Ave
# 18               -73.990985          3725.0              2 Ave & E 72 St
# 19               -73.965903           307.0        Canal St & Rutgers St
# 20               -74.002150           284.0        Greenwich Ave & 8 Ave
# 21               -73.953517          3370.0              E 78 St & 2 Ave
# 22               -73.992663           349.0      Rivington St & Ridge St
# 23               -73.928360          3429.0       Hanson Pl & Ashland Pl
# 24               -73.948920          3312.0              1 Ave & E 94 St
#
#     end station latitude  end station longitude  bikeid    usertype  \
# 0              40.710762             -73.994004   35305  Subscriber
# 1              40.686744             -73.990632   38822  Subscriber
# 2              40.682800             -73.999904   18373  Subscriber
# 3              40.721101             -73.991925   25002  Subscriber
# 4              40.781721             -73.945940   31198  Subscriber
# 5              40.741459             -73.983293   21628  Subscriber
# 6              40.729538             -73.984267   25914  Subscriber
# 7              40.766741             -73.979069   34414  Subscriber
# 8              40.689622             -73.983043   28226  Subscriber
# 9              40.763441             -73.982681   33448    Customer
# 10             40.724537             -73.981854   38334  Subscriber
# 11             40.726218             -73.983799   28529  Subscriber
# 12             40.707678             -73.940162   19913  Subscriber
# 13             40.768974             -73.954823   29018  Subscriber
# 14             40.737815             -73.999947   28162  Subscriber
# 15             40.754692             -73.997402   25623  Subscriber
# 16             40.734546             -73.990741   25552    Customer
# 17             40.770513             -73.988038   26808  Subscriber
# 18             40.768762             -73.958408   31125  Subscriber
# 19             40.714275             -73.989900   38691  Subscriber
# 20             40.739017             -74.002638   26506  Subscriber
# 21             40.772797             -73.955778   33026  Subscriber
# 22             40.718502             -73.983299   20109    Customer
# 23             40.685068             -73.977908   18872  Subscriber
# 24             40.781721             -73.945940   26108  Subscriber
#
#     birth year  gender                   tripduation
# 0         1996       2 1970-01-01 00:00:00.000000393
# 1         1998       2 1970-01-01 00:00:00.000000627
# 2         1988       1 1970-01-01 00:00:00.000001132
# 3         1988       1 1970-01-01 00:00:00.000001780
# 4         1965       2 1970-01-01 00:00:00.000001517
# 5         1998       1 1970-01-01 00:00:00.000000632
# 6         1995       1 1970-01-01 00:00:00.000000117
# 7         1999       1 1970-01-01 00:00:00.000000378
# 8         1992       1 1970-01-01 00:00:00.000001102
# 9         1968       1 1970-01-01 00:00:00.000001733
# 10        1988       2 1970-01-01 00:00:00.000000885
# 11        1973       1 1970-01-01 00:00:00.000000505
# 12        1990       1 1970-01-01 00:00:00.000000620
# 13        1965       2 1970-01-01 00:00:00.000000308
# 14        1983       1 1970-01-01 00:00:00.000000645
# 15        1976       1 1970-01-01 00:00:00.000000510
# 16        1993       1 1970-01-01 00:00:00.000001758
# 17        1936       1 1970-01-01 00:00:00.000001692
# 18        1969       1 1970-01-01 00:00:00.000001332
# 19        1972       2 1970-01-01 00:00:00.000001295
# 20        1989       1 1970-01-01 00:00:00.000000506
# 21        1979       1 1970-01-01 00:00:00.000000085
# 22        1969       0 1970-01-01 00:00:00.000000440
# 23        1971       2 1970-01-01 00:00:00.000001537
# 24        1985       1 1970-01-01 00:00:00.000000824

# %%
# 5. Export the Dataframe as a new CSV file without the index.
citibike_df.to_csv('citibike')

# %%
citibike_df.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-f5d257cc0403> in <module>
# ----> 1 citibike_df.type()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'
